# %%
import pandas as pd

# %%
data = {
    'apples': [3, 2, 0, 1], 
    'oranges': [0, 3, 7, 2]
}

# %%
purchases = pd.DataFrame(data)

purchases
# Out:
#    apples  oranges
# 0       3        0
# 1       2        3
# 2       0        7
# 3       1        2

# %%
type(purchases)
# Out:
# pandas.core.frame.DataFrame

# %%
n=purchases['oranges']

# %%
type(n)
# Out:
# pandas.core.series.Series

# %%
m=purchases[['oranges','apples']]

# %%
type(m)
# Out:
# pandas.core.frame.DataFrame

# %%
purchase1=pd.DataFrame(data, index=['June', 'Robert', 'Lily', 'David'])

# %%
purchase1
# Out:
#         apples  oranges
# June         3        0
# Robert       2        3
# Lily         0        7
# David        1        2

# %%
purchase1.loc['Lily']
# Out:
# apples     0
# oranges    7
# Name: Lily, dtype: int64

# %%
purchase1.columns
# Out:
# Index(['apples', 'oranges'], dtype='object')

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\user\\OneDrive\\Data_Science'

# %%
movies = pd.read_csv("imdb2.csv",index_col='Rank')

# %%
movies
# Out:
#                                         Title                       Genre  \
# Rank
# 1                     Guardians of the Galaxy     Action,Adventure,Sci-Fi
# 2                                  Prometheus    Adventure,Mystery,Sci-Fi
# 3                                       Split             Horror,Thriller
# 4                                        Sing     Animation,Comedy,Family
# 5                               Suicide Squad    Action,Adventure,Fantasy
# 6                              The Great Wall    Action,Adventure,Fantasy
# 7                                  La La Land          Comedy,Drama,Music
# 8                                    Mindhorn                      Comedy
# 9                          The Lost City of Z  Action,Adventure,Biography
# 10                                 Passengers     Adventure,Drama,Romance
# 11    Fantastic Beasts and Where to Find Them    Adventure,Family,Fantasy
# 12                             Hidden Figures     Biography,Drama,History
# ...

# %%
movies.head(2)
# Out:
#                         Title                     Genre  \
# Rank
# 1     Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 2                  Prometheus  Adventure,Mystery,Sci-Fi
#
#                                             Description      Director  \
# Rank
# 1     A group of intergalactic criminals are forced ...    James Gunn
# 2     Following clues to the origin of mankind, a te...  Ridley Scott
#
#                                                  Actors  Year  \
# Rank
# 1     Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014
# 2     Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012
#
#       Runtime (Minutes)  Rating   Votes  Revenue (Millions)  Metascore
# Rank
# 1                   121     8.1  757074              333.13       76.0
# 2                   124     7.0  485820              126.46       65.0

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 1 to 1000
# Data columns (total 11 columns):
# Title                 1000 non-null object
# Genre                 1000 non-null object
# Description           1000 non-null object
# Director              1000 non-null object
# Actors                1000 non-null object
# Year                  1000 non-null int64
# Runtime (Minutes)     1000 non-null int64
# Rating                1000 non-null float64
# Votes                 1000 non-null int64
# Revenue (Millions)    872 non-null float64
# Metascore             936 non-null float64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 93.8+ KB

# %%
c=movies.columns

# %%
c[0]
# Out:
# 'Title'

# %%
movies.shape
# Out:
# (1000, 11)

# %%
temp=movies.append(movies)

# %%
temp.shape
# Out:
# (2000, 11)

# %%
temp=temp.append(temp)

# %%
temp.shape
# Out:
# (4000, 11)

# %%
temp.drop_duplicates(inplace=True, keep=False)

# %%
temp.shape
# Out:
# (0, 11)

# %%
movies.rename(columns={
        'Runtime (Minutes)': 'Runtime', 
        'Revenue (Millions)': 'Revenue_millions'
    }, inplace=True)


movies.columns
# Out:
# Index(['Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime', 'Rating', 'Votes', 'Revenue_millions', 'Metascore'],
#       dtype='object')

# %%
movies.columns = ['rank', 'genre', 'description', 'director', 'actors', 'year', 'runtime', 
                     'rating', 'votes', 'revenue_millions', 'metascore']


movies.columns
# Out:
# Index(['rank', 'genre', 'description', 'director', 'actors', 'year', 'runtime',
#        'rating', 'votes', 'revenue_millions', 'metascore'],
#       dtype='object')

# %%
movies.columns = [col.lower() for col in movies]

movies.columns
# Out:
# Index(['rank', 'genre', 'description', 'director', 'actors', 'year', 'runtime',
#        'rating', 'votes', 'revenue_millions', 'metascore'],
#       dtype='object')

# %%
for x in movies:
    print(x)
# Out:
# rank
# genre
# description
# director
# actors
# year
# runtime
# rating
# votes
# revenue_millions
# metascore

# %%
temp1=movies.copy()
temp1.dropna(inplace=True)

# %%
temp1.shape
# Out:
# (838, 11)

# %%
movies['revenue_millions'].fillna(movies['revenue_millions'].mean(),inplace=True)
movies['metascore'].fillna(movies['metascore'].mean(),inplace=True)

# %%
movies.isnull().sum()
# Out:
# rank                0
# genre               0
# description         0
# director            0
# actors              0
# year                0
# runtime             0
# rating              0
# votes               0
# revenue_millions    0
# metascore           0
# dtype: int64

# %%
movies.describe()
# Out:
#               year      runtime       rating         votes  revenue_millions  \
# count  1000.000000  1000.000000  1000.000000  1.000000e+03       1000.000000
# mean   2012.783000   113.172000     6.723200  1.698083e+05         82.956376
# std       3.205962    18.810908     0.945429  1.887626e+05         96.412043
# min    2006.000000    66.000000     1.900000  6.100000e+01          0.000000
# 25%    2010.000000   100.000000     6.200000  3.630900e+04         17.442500
# 50%    2014.000000   111.000000     6.800000  1.107990e+05         60.375000
# 75%    2016.000000   123.000000     7.400000  2.399098e+05         99.177500
# max    2016.000000   191.000000     9.000000  1.791916e+06        936.630000
#
#          metascore
# count  1000.000000
# mean     58.985043
# std      16.634858
# min      11.000000
# 25%      47.750000
# 50%      58.985043
# 75%      71.000000
# max     100.000000

# %%
movies['rating'].value_counts().sort_values(ascending=True)
# Out:
# 1.9     1
# 9.0     1
# 3.2     1
# 4.1     1
# 4.5     1
# 4.4     1
# 4.0     1
# 3.7     2
# 3.5     2
# 4.2     2
# 2.7     2
# 8.8     2
# 8.6     3
# 3.9     3
# 5.0     4
# 4.8     4
# 4.3     4
# 8.4     4
# 5.1     5
# 4.6     5
# 8.5     6
# 4.7     6
# 8.3     7
# 4.9     7
# 8.2    10
# 5.2    11
# 5.4    12
# 5.3    12
# 5.5    14
# 5.6    17
# 5.9    19
# 8.0    19
# 5.7    21
# 7.9    23
# 8.1    26
# 6.0    26
# 5.8    26
# 7.7    27
# 7.6    27
# 6.1    31
# 6.9    31
# 7.4    33
# 6.4    35
# 7.5    35
# 6.8    37
# 6.2    37
# 7.8    40
# 6.5    40
# 7.3    42
# 7.2    42
# 6.6    42
# 6.3    44
# 7.0    46
# 6.7    48
# 7.1    52
# Name: rating, dtype: int64

# %%
x= movies['rating']==5.0

# %%
movies[x]
# Out:
#                rank                    genre  \
# Rank
# 394   Whisky Galore           Comedy,Romance
# 513   The Happening          Sci-Fi,Thriller
# 755    Lída Baarová  Biography,Drama,History
# 978   Amateur Night                   Comedy
#
#                                             description            director  \
# Rank
# 394   Scottish islanders try to plunder cases of whi...   Gillies MacKinnon
# 513   A science teacher, his wife, and a young girl ...  M. Night Shyamalan
# 755   A film about the black-and-white era actress L...          Filip Renc
# 978   Guy Carter is an award-winning graduate studen...        Lisa Addario
#
#                                                  actors  year  runtime  \
# Rank
# 394   Tim Pigott-Smith, Naomi Battrick, Ellie Kendri...  2016       98
# 513   Mark Wahlberg, Zooey Deschanel, John Leguizamo...  2008       91
# 755   Tatiana Pauhofová, Karl Markovics, Gedeon Burk...  2016      106
# ...

# %%
data2 = pd.read_json('https://jsonplaceholder.typicode.com/todos')

# %%
data2.head(5)
# Out:
#    completed  id                                              title  userId
# 0      False   1                                 delectus aut autem       1
# 1      False   2                 quis ut nam facilis et officia qui       1
# 2      False   3                                fugiat veniam minus       1
# 3       True   4                                   et porro tempora       1
# 4      False   5  laboriosam mollitia et enim quasi adipisci qui...       1

# %%
data2.set_index('id')
# Out:
#      completed                                              title  userId
# id
# 1        False                                 delectus aut autem       1
# 2        False                 quis ut nam facilis et officia qui       1
# 3        False                                fugiat veniam minus       1
# 4         True                                   et porro tempora       1
# 5        False  laboriosam mollitia et enim quasi adipisci qui...       1
# 6        False  qui ullam ratione quibusdam voluptatem quia omnis       1
# 7        False                  illo expedita consequatur quia in       1
# 8         True                       quo adipisci enim quam ut ab       1
# 9        False                        molestiae perspiciatis ipsa       1
# 10        True       illo est ratione doloremque quia maiores aut       1
# 11        True                        vero rerum temporibus dolor       1
# 12        True                        ipsa repellendus fugit nisi       1
# ...

# %%
# !pip install psycopg2
# Out:
# ...
# twisted 18.7.0 requires PyHamcrest>=1.9.0, which is not installed.
# You are using pip version 10.0.1, however version 20.0.2 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import psycopg2 as ps

# %%
conn=ps.connect(user="postgres",password="cinadhis99",host="localhost",dbname="sales_demo")

# %%
query="select * from inventories"

# %%
pdinvent = pd.read_sql(query,conn)

# %%
pdinvent.head(2)
# Out:
#    id                  name  buyingprice  sellingprice        type
# 0   1  Compound - Raspberry       197.32        276.25  Vegetables
# 1   2  Pastry - Apple Large       198.40        277.76       Fruit

# %%
pdinvent.set_index('id')
# Out:
#                                  name  buyingprice  sellingprice        type
# id
# 1                Compound - Raspberry       197.32        276.25  Vegetables
# 2                Pastry - Apple Large       198.40        277.76       Fruit
# 3                   Bacardi Raspberry       174.64        244.50       Fruit
# 4        Wine - Gewurztraminer Pierre       199.96        279.94  Vegetables
# 5        Dawn Professionl Pot And Pan       179.17        250.84  Vegetables
# 6                  Cranberry Foccacia       186.95        261.73       Fruit
# 7                Worcestershire Sauce       169.61        237.45  Vegetables
# 8                 Curry Powder Madras       173.22        242.51  Vegetables
# 9                  Cookies Cereal Nut       173.12        242.37       Fruit
# 10                       Durian Fruit       198.46        277.84  Vegetables
# 11         Salmon Atl.whole 8 - 10 Lb       159.81        223.73  Vegetables
# ...

# %%
pdinvent.to_csv('new_inves.csv')

# %%
# !pip install SQLAlchemy
# Out:
# ...
# twisted 18.7.0 requires PyHamcrest>=1.9.0, which is not installed.
# You are using pip version 10.0.1, however version 20.0.2 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
from sqlalchemy import create_engine

# %%
engine=create_engine('postgresql://postgres:cinadhis99@localhost:5432/sales_demo')

# %%
#data2.to_sql('todos',engine)
